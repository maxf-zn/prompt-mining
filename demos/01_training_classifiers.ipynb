# %% [markdown]
# # Training Classifiers on Stored Activations
#
# This notebook demonstrates how to train malicious prompt classifiers using pre-extracted model activations.
#
# ## Overview
#
# The `prompt_mining.classifiers` module provides:
# - **ClassificationDataset**: Load pre-extracted activations from the ingestion pipeline
# - **LinearClassifier**: Sklearn-based logistic regression with configurable normalization
# - **DANNClassifier**: Domain-Adversarial Neural Network for cross-dataset generalization
# - **lodo_evaluate**: Leave-One-Dataset-Out evaluation for testing generalization
# - **Threshold Strategies**: Pluggable threshold selection (constant, target precision, max F1)

# %%
from prompt_mining.classifiers import (
    # Data loading
    ClassificationDataset,
    # Classifiers
    LinearClassifier,
    LinearConfig,
    DANNClassifier,
    DANNConfig,
    # Evaluation
    lodo_evaluate,
    # Threshold strategies
    ConstantThreshold,
    TargetPrecisionThreshold,
    MaxF1Threshold,
    CVConfig,
)

import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Loading Pre-Extracted Activations
#
# The `ClassificationDataset` class loads activations from directories created by the ingestion pipeline.
#
# **Key parameters for `.load()`:**
# - `layer`: Which model layer to load (e.g., 27, 31)
# - `space`: `'raw'` for model activations, `'sae'` for SAE-encoded features
# - `position`: Token position (`'last'`, `'-5'`, `0`, etc.)
# - `return_sparse`: Whether to return sparse matrix (for SAE features)

# %%
# Load dataset from ingestion output directory
# Update this path to point to your ingestion output
dataset = ClassificationDataset.from_path("/path/to/activations")

# Load raw (dense) activations at layer 31
data_raw = dataset.load(layer=31, space='raw', position=[-5])
print(dataset.summary(data_raw))
# Out:
# Loaded from cache: raw_layer31_pos-5.npz
# ClassificationDataset Summary
# ========================================
# Samples: 105034
# Features: 4096
# Datasets: 18
# Class balance: 46.7% positive
#
# Per-dataset breakdown:
#   bipia_email_code_table: 15000 samples (95.3% positive)
#   dolly_15k: 10000 samples (0.0% positive)
#   enron: 10000 samples (0.0% positive)
#   jayavibhav: 10000 samples (49.7% positive)
#   mosscap: 10000 samples (100.0% positive)
#   llmail: 9998 samples (100.0% positive)
#   openorca: 9997 samples (0.0% positive)
#   10k_prompts_ranked: 9924 samples (0.0% positive)
#   safeguard: 8236 samples (30.3% positive)
#   qualifire: 5000 samples (40.0% positive)
#   wildjailbreak: 2210 samples (90.5% positive)
#   injecagent_dh_ds_base: 1054 samples (100.0% positive)
#   yanismiraoui: 1034 samples (100.0% positive)
#   softAge: 1001 samples (0.0% positive)
#   deepset: 546 samples (37.2% positive)
#   advbench: 520 samples (100.0% positive)
#   harmbench: 400 samples (100.0% positive)
#   gandalf_summarization: 114 samples (100.0% positive)

# %%
# Load SAE-encoded features (sparse matrix for memory efficiency)
data_sae = dataset.load(layer=27, space='sae', position=[-5], return_sparse=True)
print(f"SAE data loaded: {data_sae.X.shape}")
print(f"Sparsity: {1 - data_sae.X.nnz / np.prod(data_sae.X.shape):.2%}")
# Out:
# Loaded from cache: sae_layer27_pos-5_sparse.npz
# SAE data loaded: (105034, 131072)
# Sparsity: 99.17%

# %% [markdown]
# ## 2. Training a Linear Classifier
#
# The `LinearClassifier` wraps sklearn's logistic regression with configurable normalization.
#
# **LinearConfig options:**
# - `model`: `'logistic'` (L-BFGS) or `'sgd'` (SGD optimizer)
# - `normalize`: `'standard'` (z-score), `'l2'` (unit norm), `'none'`
# - `C`: Inverse regularization strength (higher = less regularization)

# %%
from sklearn.model_selection import train_test_split

# Train a linear classifier on raw activations
clf_raw = LinearClassifier(LinearConfig(
    model='logistic',
    normalize='standard',
    C=0.1
))

# Simple train/test split for demonstration
X_train, X_test, y_train, y_test = train_test_split(
    data_raw.X, data_raw.y, test_size=0.2, random_state=42, stratify=data_raw.y
)

clf_raw.fit(X_train, y_train)
print(f"Trained: {clf_raw}")

# Evaluate
test_scores = clf_raw.predict_scores(X_test)
test_acc = ((test_scores >= 0.5).astype(int) == y_test).mean()
print(f"Test accuracy: {test_acc:.1%}")
# Out:
# Trained: LinearClassifier(model=logistic, normalize=standard, fitted)
# Test accuracy: 97.8%

# %% [markdown]
# ## 3. LODO Evaluation (Leave-One-Dataset-Out)
#
# Random train/test splits can overestimate performance when samples from the same dataset appear in both sets. **LODO evaluation** tests true cross-dataset generalization:
#
# 1. For each dataset D: train on ALL other datasets, test on D
# 2. Report per-dataset metrics + weighted average
#
# This reveals which datasets are "out-of-distribution" relative to others.

# %%
# LODO evaluation with constant threshold
clf = LinearClassifier(LinearConfig(model='logistic', normalize='standard', C=0.1))

results_constant = lodo_evaluate(
    clf,
    data_raw.X,
    data_raw.y,
    data_raw.datasets,
    threshold_strategy=ConstantThreshold(0.5),
    # Merge similar datasets for fair estimates
    merge_datasets={'gandalf_summarization': 'mosscap'},
)
# Out:
# Threshold strategy: constant(0.5), CV: False
# Evaluating on 10k_prompts_ranked (9924 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=92.4%, F1=0.0%, thr=0.500
# Evaluating on advbench (520 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=90.8%, F1=95.2%, thr=0.500
# Evaluating on bipia_email_code_table (15000 samples)... acc=63.1%, F1=76.7%, thr=0.500
# Evaluating on deepset (546 samples)... acc=77.7%, F1=63.5%, thr=0.500
# Evaluating on dolly_15k (10000 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=99.6%, F1=0.0%, thr=0.500
# Evaluating on enron (10000 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=82.6%, F1=0.0%, thr=0.500
# Evaluating on harmbench (400 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=42.8%, F1=59.9%, thr=0.500
# Evaluating on injecagent_dh_ds_base (1054 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=98.9%, F1=99.4%, thr=0.500
# Evaluating on jayavibhav (10000 samples)... acc=69.1%, F1=72.3%, thr=0.500
# Evaluating on llmail (9998 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=71.4%, F1=83.3%, thr=0.500
# Evaluating on mosscap (10114 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=79.4%, F1=88.5%, thr=0.500
# Evaluating on openorca (9997 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=98.0%, F1=0.0%, thr=0.500
# Evaluating on qualifire (5000 samples)... acc=77.8%, F1=74.5%, thr=0.500
# Evaluating on safeguard (8236 samples)... acc=96.7%, F1=94.5%, thr=0.500
# Evaluating on softAge (1001 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=95.1%, F1=0.0%, thr=0.500
# Evaluating on wildjailbreak (2210 samples)... acc=78.6%, F1=87.0%, thr=0.500
# Evaluating on yanismiraoui (1034 samples)... acc=55.8%, F1=71.6%, thr=0.500
# --------------------------------------------------
# Weighted average: acc=81.8%, F1=49.8%
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(

# %% [markdown]
# ## 4. Threshold Strategies
#
# Different threshold selection strategies affect precision/recall tradeoffs:
#
# - **ConstantThreshold(0.5)**: Fixed threshold at 0.5
# - **TargetPrecisionThreshold(0.95)**: Select threshold to achieve 95% precision on benign class
# - **MaxF1Threshold()**: Select threshold that maximizes F1 score
#
# Use **CVConfig** to generate calibrated scores via cross-validation before threshold selection.

# %%
# Target precision strategy with cross-validation
results_precision = lodo_evaluate(
    clf,
    data_raw.X,
    data_raw.y,
    data_raw.datasets,
    threshold_strategy=TargetPrecisionThreshold(0.95),
    cv=CVConfig(enabled=True, folds=3, n_jobs=8),
    merge_datasets={'gandalf_summarization': 'mosscap'},
)
# Out:
# Threshold strategy: precision(0.95), CV: True
# Evaluating on 10k_prompts_ranked (9924 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=85.6%, F1=0.0%, thr=0.075
# Evaluating on advbench (520 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=93.7%, F1=96.7%, thr=0.081
# Evaluating on bipia_email_code_table (15000 samples)... acc=76.6%, F1=86.6%, thr=0.077
# Evaluating on deepset (546 samples)... acc=78.0%, F1=67.4%, thr=0.072
# Evaluating on dolly_15k (10000 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=99.2%, F1=0.0%, thr=0.112
# Evaluating on enron (10000 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=71.9%, F1=0.0%, thr=0.102
# Evaluating on harmbench (400 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=51.2%, F1=67.8%, thr=0.064
# Evaluating on injecagent_dh_ds_base (1054 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=100.0%, F1=100.0%, thr=0.079
# Evaluating on jayavibhav (10000 samples)... acc=62.1%, F1=70.3%, thr=0.032
# Evaluating on llmail (9998 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=86.9%, F1=93.0%, thr=0.075
# Evaluating on mosscap (10114 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=87.3%, F1=93.2%, thr=0.088
# Evaluating on openorca (9997 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=95.0%, F1=0.0%, thr=0.129
# Evaluating on qualifire (5000 samples)... acc=75.1%, F1=73.9%, thr=0.028
# Evaluating on safeguard (8236 samples)... acc=96.7%, F1=94.7%, thr=0.082
# Evaluating on softAge (1001 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=89.2%, F1=0.0%, thr=0.080
# Evaluating on wildjailbreak (2210 samples)... acc=86.0%, F1=92.1%, thr=0.054
# Evaluating on yanismiraoui (1034 samples)... acc=74.4%, F1=85.3%, thr=0.069
# --------------------------------------------------
# Weighted average: acc=83.6%, F1=52.7%
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(

# %% [markdown]
# ## 5. DANN Classifier (Domain Adversarial)
#
# The `DANNClassifier` learns domain-invariant representations by adversarially training against dataset prediction. This can improve cross-dataset generalization.
#
# **DANNConfig options:**
# - `hidden_layers`: MLP architecture (default: [512, 256, 64])
# - `domain_weight`: Weight of adversarial loss (0 = no adversarial training)
# - `lr`: Learning rate
# - `max_epochs`: Maximum training epochs
# - `early_stopping_patience`: Epochs to wait before early stopping

# %%
# DANN classifier (neural network with optional domain adversarial training)
dann = DANNClassifier(DANNConfig())

results_dann = lodo_evaluate(
    dann,
    data_raw.X,
    data_raw.y,
    data_raw.datasets,
    threshold_strategy=ConstantThreshold(0.5),
    merge_datasets={'gandalf_summarization': 'mosscap'},
)
# Out:
# Threshold strategy: constant(0.5), CV: False
# Evaluating on 10k_prompts_ranked (9924 samples)...
# Training DANN:  63%|██████▎   | 63/100 [01:28<00:51,  1.40s/it]
# Early stopping at epoch 63
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=92.4%, F1=0.0%, thr=0.500
# Evaluating on advbench (520 samples)...
# Training DANN:  42%|████▏     | 42/100 [01:06<01:31,  1.57s/it]
# Early stopping at epoch 42
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=97.1%, F1=98.5%, thr=0.500
# Evaluating on bipia_email_code_table (15000 samples)...
# Training DANN:  63%|██████▎   | 63/100 [01:24<00:49,  1.34s/it]
# Early stopping at epoch 63
# acc=60.1%, F1=74.6%, thr=0.500
# Evaluating on deepset (546 samples)...
# Training DANN:  45%|████▌     | 45/100 [01:10<01:25,  1.56s/it]
# Early stopping at epoch 45
# acc=78.4%, F1=62.4%, thr=0.500
# Evaluating on dolly_15k (10000 samples)...
# Training DANN:  40%|████      | 40/100 [00:55<01:23,  1.39s/it]
# Early stopping at epoch 40
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=99.8%, F1=0.0%, thr=0.500
# Evaluating on enron (10000 samples)...
# Training DANN:  60%|██████    | 60/100 [01:23<00:55,  1.40s/it]
# Early stopping at epoch 60
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=81.1%, F1=0.0%, thr=0.500
# Evaluating on harmbench (400 samples)...
# Training DANN:  39%|███▉      | 39/100 [01:01<01:36,  1.57s/it]
# Early stopping at epoch 39
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=44.8%, F1=61.8%, thr=0.500
# Evaluating on injecagent_dh_ds_base (1054 samples)...
# Training DANN:  38%|███▊      | 38/100 [00:59<01:36,  1.56s/it]
# Early stopping at epoch 38
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=100.0%, F1=100.0%, thr=0.500
# Evaluating on jayavibhav (10000 samples)...
# Training DANN:  41%|████      | 41/100 [00:55<01:20,  1.36s/it]
# Early stopping at epoch 41
# acc=75.6%, F1=77.4%, thr=0.500
# Evaluating on llmail (9998 samples)...
# Training DANN:  70%|███████   | 70/100 [01:37<00:41,  1.39s/it]
# Early stopping at epoch 70
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=45.8%, F1=62.8%, thr=0.500
# Evaluating on mosscap (10114 samples)...
# Training DANN:  43%|████▎     | 43/100 [01:01<01:21,  1.43s/it]
# Early stopping at epoch 43
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=84.4%, F1=91.5%, thr=0.500
# Evaluating on openorca (9997 samples)...
# Training DANN:  77%|███████▋  | 77/100 [01:48<00:32,  1.41s/it]
# Early stopping at epoch 77
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=98.9%, F1=0.0%, thr=0.500
# Evaluating on qualifire (5000 samples)...
# Training DANN:  48%|████▊     | 48/100 [01:10<01:16,  1.47s/it]
# Early stopping at epoch 48
# acc=77.8%, F1=74.9%, thr=0.500
# Evaluating on safeguard (8236 samples)...
# Training DANN:  29%|██▉       | 29/100 [00:41<01:42,  1.45s/it]
# Early stopping at epoch 29
# acc=97.4%, F1=95.6%, thr=0.500
# Evaluating on softAge (1001 samples)...
# Training DANN:  48%|████▊     | 48/100 [01:14<01:21,  1.56s/it]
# Early stopping at epoch 48
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=96.4%, F1=0.0%, thr=0.500
# Evaluating on wildjailbreak (2210 samples)...
# Training DANN:  58%|█████▊    | 58/100 [01:29<01:04,  1.55s/it]
# Early stopping at epoch 58
# acc=79.6%, F1=87.7%, thr=0.500
# Evaluating on yanismiraoui (1034 samples)...
# Training DANN:  51%|█████     | 51/100 [01:20<01:16,  1.57s/it]
# Early stopping at epoch 51
# acc=45.6%, F1=62.6%, thr=0.500
# --------------------------------------------------
# Weighted average: acc=80.1%, F1=48.4%
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(

# %% [markdown]
# ## 6. SAE Features Classifier
#
# SAE (Sparse Autoencoder) features provide interpretable dimensions. Use L2 normalization for sparse features.

# %%
# SAE classifier with L2 normalization
clf_sae = LinearClassifier(LinearConfig(model='logistic', normalize='l2', C=1.0))

results_sae = lodo_evaluate(
    clf_sae,
    data_sae.X,
    data_sae.y,
    data_sae.datasets,
    threshold_strategy=ConstantThreshold(0.5),
    merge_datasets={'gandalf_summarization': 'mosscap'},
)
# Out:
# Threshold strategy: constant(0.5), CV: False
# Evaluating on 10k_prompts_ranked (9924 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=89.1%, F1=0.0%, thr=0.500
# Evaluating on advbench (520 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=92.9%, F1=96.3%, thr=0.500
# Evaluating on bipia_email_code_table (15000 samples)... acc=26.1%, F1=36.8%, thr=0.500
# Evaluating on deepset (546 samples)... acc=80.6%, F1=66.9%, thr=0.500
# Evaluating on dolly_15k (10000 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=99.8%, F1=0.0%, thr=0.500
# Evaluating on enron (10000 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=85.7%, F1=0.0%, thr=0.500
# Evaluating on harmbench (400 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=36.2%, F1=53.2%, thr=0.500
# Evaluating on injecagent_dh_ds_base (1054 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=100.0%, F1=100.0%, thr=0.500
# Evaluating on jayavibhav (10000 samples)... acc=76.6%, F1=73.1%, thr=0.500
# Evaluating on llmail (9998 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=58.4%, F1=73.7%, thr=0.500
# Evaluating on mosscap (10114 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=65.2%, F1=78.9%, thr=0.500
# Evaluating on openorca (9997 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=98.3%, F1=0.0%, thr=0.500
# Evaluating on qualifire (5000 samples)... acc=76.5%, F1=74.5%, thr=0.500
# Evaluating on safeguard (8236 samples)... acc=95.7%, F1=92.7%, thr=0.500
# Evaluating on softAge (1001 samples)...
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1131: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# acc=95.6%, F1=0.0%, thr=0.500
# Evaluating on wildjailbreak (2210 samples)... acc=80.7%, F1=88.5%, thr=0.500
# Evaluating on yanismiraoui (1034 samples)... acc=41.9%, F1=59.0%, thr=0.500
# --------------------------------------------------
# Weighted average: acc=74.5%, F1=42.1%
# /home/azureuser/uv-global/.venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:442: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(

# %% [markdown]
# ## 7. Results Comparison
#
# Compare all methods across datasets. Each row is a dataset (held out during training), columns are different classifier configurations.

# %%
# Collect all results
all_results = {
    'Linear (t=0.5)': results_constant,
    'Linear (p=0.95)': results_precision,
    'DANN': results_dann,
    'SAE Linear': results_sae,
}

# Build per-dataset comparison tables
acc_data = {}
f1_data = {}

for method_name, results in all_results.items():
    for ds_name, metrics in results.per_dataset.items():
        if ds_name not in acc_data:
            acc_data[ds_name] = {}
            f1_data[ds_name] = {}
        acc_data[ds_name][method_name] = metrics['acc'] * 100
        f1_data[ds_name][method_name] = metrics['malicious_f1']

# Create DataFrames
df_acc = pd.DataFrame(acc_data).T.sort_index()
df_f1 = pd.DataFrame(f1_data).T.sort_index()

# Add weighted average row
avg_row_acc = {name: res.weighted_average['acc'] * 100 for name, res in all_results.items()}
avg_row_f1 = {name: res.weighted_average['malicious_f1'] for name, res in all_results.items()}
df_acc.loc['WEIGHTED AVG'] = avg_row_acc
df_f1.loc['WEIGHTED AVG'] = avg_row_f1

# Display Accuracy table with colors
print("Accuracy by Dataset (%)")
print("=" * 80)
display(df_acc.style
    .format('{:.1f}')
    .background_gradient(cmap='RdYlGn', vmin=0, vmax=100)
    .set_properties(**{'font-size': '15px'})
)
# Out:
# Accuracy by Dataset (%)
# ================================================================================
# <style type="text/css">
# #T_3b179_row0_col0, #T_3b179_row0_col2 {
#   background-color: #138c4a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row0_col1, #T_3b179_row5_col3 {
#   background-color: #39a758;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row0_col3, #T_3b179_row14_col1 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row1_col0 {
#   background-color: #17934e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row1_col1 {
#   background-color: #108647;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row1_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row1_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row2_col0 {
#   background-color: #c9e881;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row2_col1, #T_3b179_row8_col3 {
#   background-color: #7ac665;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row2_col2 {
#   background-color: #d9ef8b;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row2_col3 {
#   background-color: #f99355;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row3_col0 {
#   background-color: #75c465;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row3_col1, #T_3b179_row12_col0, #T_3b179_row12_col2 {
#   background-color: #73c264;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row3_col2 {
#   background-color: #70c164;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row3_col3, #T_3b179_row15_col3 {
#   background-color: #60ba62;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row4_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row4_col1, #T_3b179_row7_col0, #T_3b179_row11_col2 {
#   background-color: #026c39;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row4_col2, #T_3b179_row4_col3, #T_3b179_row7_col1, #T_3b179_row7_col2, #T_3b179_row7_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row5_col0 {
#   background-color: #51b35e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row5_col1 {
#   background-color: #9bd469;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row5_col2 {
#   background-color: #5db961;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row6_col0 {
#   background-color: #fee999;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row6_col1 {
#   background-color: #fafdb8;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row6_col2 {
#   background-color: #feefa3;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row6_col3 {
#   background-color: #fecc7b;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row8_col0 {
#   background-color: #abdb6d;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row8_col1 {
#   background-color: #cdea83;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row8_col2 {
#   background-color: #82c966;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row9_col0 {
#   background-color: #9dd569;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row9_col1 {
#   background-color: #30a356;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row9_col2 {
#   background-color: #fff2aa;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row9_col3 {
#   background-color: #dff293;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row10_col0, #T_3b179_row15_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row10_col1 {
#   background-color: #2da155;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row10_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row10_col3 {
#   background-color: #bfe47a;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row11_col0 {
#   background-color: #05713c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row11_col1, #T_3b179_row14_col0 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row11_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row12_col1 {
#   background-color: #84ca66;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row12_col3 {
#   background-color: #7dc765;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row13_col0, #T_3b179_row13_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row13_col2 {
#   background-color: #06733d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row13_col3 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row14_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row14_col3 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row15_col0 {
#   background-color: #6ec064;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row15_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row16_col0 {
#   background-color: #e9f6a1;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row16_col1, #T_3b179_row17_col3 {
#   background-color: #89cc67;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row16_col2 {
#   background-color: #fff1a8;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row16_col3 {
#   background-color: #fee695;
#   color: #000000;
#   font-size: 15px;
# }
# #T_3b179_row17_col0 {
#   background-color: #57b65f;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row17_col1 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_3b179_row17_col2 {
#   background-color: #66bd63;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# </style>
# <table id="T_3b179">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b179_level0_col0" class="col_heading level0 col0" >Linear (t=0.5)</th>
#       <th id="T_3b179_level0_col1" class="col_heading level0 col1" >Linear (p=0.95)</th>
#       <th id="T_3b179_level0_col2" class="col_heading level0 col2" >DANN</th>
#       <th id="T_3b179_level0_col3" class="col_heading level0 col3" >SAE Linear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b179_level0_row0" class="row_heading level0 row0" >10k_prompts_ranked</th>
#       <td id="T_3b179_row0_col0" class="data row0 col0" >92.4</td>
#       <td id="T_3b179_row0_col1" class="data row0 col1" >85.6</td>
#       <td id="T_3b179_row0_col2" class="data row0 col2" >92.4</td>
#       <td id="T_3b179_row0_col3" class="data row0 col3" >89.1</td>
#     </tr>
#     <tr>
#       <th id="T_3b179_level0_row1" class="row_heading level0 row1" >advbench</th>
#       <td id="T_3b179_row1_col0" class="data row1 col0" >90.8</td>
#       <td id="T_3b179_row1_col1" class="data row1 col1" >93.7</td>
#       <td id="T_3b179_row1_col2" class="data row1 col2" >97.1</td>
#       <td id="T_3b179_row1_col3" class="data row1 col3" >92.9</td>
#     </tr>
#     <tr>
#       <th id="T_3b179_level0_row2" class="row_heading level0 row2" >bipia_email_code_table</th>
#       <td id="T_3b179_row2_col0" class="data row2 col0" >63.1</td>
#       <td id="T_3b179_row2_col1" class="data row2 col1" >76.6</td>
#       <td id="T_3b179_row2_col2" class="data row2 col2" >60.1</td>
#       <td id="T_3b179_row2_col3" class="data row2 col3" >26.1</td>
#     </tr>
#     <tr>
#       <th id="T_3b179_level0_row3" class="row_heading level0 row3" >deepset</th>
#       <td id="T_3b179_row3_col0" class="data row3 col0" >77.7</td>
#       <td id="T_3b179_row3_col1" class="data row3 col1" >78.0</td>
#       <td id="T_3b179_row3_col2" class="data row3 col2" >78.4</td>
#       <td id="T_3b179_row3_col3" class="data row3 col3" >80.6</td>
#     </tr>
#     <tr>
#       <th id="T_3b179_level0_row4" class="row_heading level0 row4" >dolly_15k</th>
#       <td id="T_3b179_row4_col0" class="data row4 col0" >99.6</td>
#       <td id="T_3b179_row4_col1" class="data row4 col1" >99.2</td>
#       <td id="T_3b179_row4_col2" class="data row4 col2" >99.8</td>
#       <td id="T_3b179_row4_col3" class="data row4 col3" >99.8</td>
#     </tr>
#     <tr>
#       <th id="T_3b179_level0_row5" class="row_heading level0 row5" >enron</th>
#       <td id="T_3b179_row5_col0" class="data row5 col0" >82.6</td>
#       <td id="T_3b179_row5_col1" class="data row5 col1" >71.9</td>
#       <td id="T_3b179_row5_col2" class="data row5 col2" >81.1</td>
#       <td id="T_3b179_row5_col3" class="data row5 col3" >85.7</td>
#     </tr>
#     <tr>

# %%
# Display F1 table with colors
print("F1 Score by Dataset (%)")
print("=" * 80)
display(df_f1.style
    .format('{:.1f}')
    .background_gradient(cmap='RdYlGn', vmin=0, vmax=100)
    .set_properties(**{'font-size': '15px'})
)
# Out:
# F1 Score by Dataset (%)
# ================================================================================
# <style type="text/css">
# #T_710a7_row0_col0, #T_710a7_row0_col1, #T_710a7_row0_col2, #T_710a7_row0_col3, #T_710a7_row4_col0, #T_710a7_row4_col1, #T_710a7_row4_col2, #T_710a7_row4_col3, #T_710a7_row5_col0, #T_710a7_row5_col1, #T_710a7_row5_col2, #T_710a7_row5_col3, #T_710a7_row11_col0, #T_710a7_row11_col1, #T_710a7_row11_col2, #T_710a7_row11_col3, #T_710a7_row14_col0, #T_710a7_row14_col1, #T_710a7_row14_col2, #T_710a7_row14_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row1_col0 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row1_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row1_col2 {
#   background-color: #036e3a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row1_col3 {
#   background-color: #097940;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row2_col0 {
#   background-color: #7ac665;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row2_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row2_col2, #T_710a7_row12_col0, #T_710a7_row12_col3 {
#   background-color: #89cc67;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row2_col3 {
#   background-color: #fed07e;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row3_col0 {
#   background-color: #c7e77f;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row3_col1 {
#   background-color: #b3df72;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row3_col2 {
#   background-color: #cdea83;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row3_col3 {
#   background-color: #b5df74;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row6_col0 {
#   background-color: #d9ef8b;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row6_col1 {
#   background-color: #b1de71;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row6_col2 {
#   background-color: #cfeb85;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row6_col3 {
#   background-color: #f2faae;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row7_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row7_col1, #T_710a7_row7_col2, #T_710a7_row7_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row8_col0 {
#   background-color: #96d268;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row8_col1 {
#   background-color: #a5d86a;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row8_col2 {
#   background-color: #75c465;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row8_col3 {
#   background-color: #91d068;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row9_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row9_col1, #T_710a7_row10_col1 {
#   background-color: #118848;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row9_col2, #T_710a7_row16_col2 {
#   background-color: #cbe982;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row9_col3 {
#   background-color: #8ecf67;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row10_col0, #T_710a7_row15_col3 {
#   background-color: #249d53;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row10_col2 {
#   background-color: #15904c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row10_col3 {
#   background-color: #6ec064;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row12_col1 {
#   background-color: #8ccd67;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row12_col2 {
#   background-color: #87cb67;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row13_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row13_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row13_col2 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row13_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row15_col0 {
#   background-color: #30a356;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row15_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row15_col2 {
#   background-color: #2aa054;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row16_col0 {
#   background-color: #9bd469;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row16_col1 {
#   background-color: #3ca959;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_710a7_row16_col3 {
#   background-color: #dcf08f;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row17_col0 {
#   background-color: #fffebe;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row17_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row17_col2 {
#   background-color: #fffab6;
#   color: #000000;
#   font-size: 15px;
# }
# #T_710a7_row17_col3 {
#   background-color: #fee695;
#   color: #000000;
#   font-size: 15px;
# }
# </style>
# <table id="T_710a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_710a7_level0_col0" class="col_heading level0 col0" >Linear (t=0.5)</th>
#       <th id="T_710a7_level0_col1" class="col_heading level0 col1" >Linear (p=0.95)</th>
#       <th id="T_710a7_level0_col2" class="col_heading level0 col2" >DANN</th>
#       <th id="T_710a7_level0_col3" class="col_heading level0 col3" >SAE Linear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_710a7_level0_row0" class="row_heading level0 row0" >10k_prompts_ranked</th>
#       <td id="T_710a7_row0_col0" class="data row0 col0" >0.0</td>
#       <td id="T_710a7_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_710a7_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_710a7_row0_col3" class="data row0 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_710a7_level0_row1" class="row_heading level0 row1" >advbench</th>
#       <td id="T_710a7_row1_col0" class="data row1 col0" >95.2</td>
#       <td id="T_710a7_row1_col1" class="data row1 col1" >96.7</td>
#       <td id="T_710a7_row1_col2" class="data row1 col2" >98.5</td>
#       <td id="T_710a7_row1_col3" class="data row1 col3" >96.3</td>
#     </tr>
#     <tr>
#       <th id="T_710a7_level0_row2" class="row_heading level0 row2" >bipia_email_code_table</th>
#       <td id="T_710a7_row2_col0" class="data row2 col0" >76.7</td>
#       <td id="T_710a7_row2_col1" class="data row2 col1" >86.6</td>
#       <td id="T_710a7_row2_col2" class="data row2 col2" >74.6</td>
#       <td id="T_710a7_row2_col3" class="data row2 col3" >36.8</td>
#     </tr>
#     <tr>
#       <th id="T_710a7_level0_row3" class="row_heading level0 row3" >deepset</th>
#       <td id="T_710a7_row3_col0" class="data row3 col0" >63.5</td>
#       <td id="T_710a7_row3_col1" class="data row3 col1" >67.4</td>
#       <td id="T_710a7_row3_col2" class="data row3 col2" >62.4</td>
#       <td id="T_710a7_row3_col3" class="data row3 col3" >66.9</td>
#     </tr>
#     <tr>
#       <th id="T_710a7_level0_row4" class="row_heading level0 row4" >dolly_15k</th>
#       <td id="T_710a7_row4_col0" class="data row4 col0" >0.0</td>
#       <td id="T_710a7_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_710a7_row4_col2" class="data row4 col2" >0.0</td>
#       <td id="T_710a7_row4_col3" class="data row4 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_710a7_level0_row5" class="row_heading level0 row5" >enron</th>
#       <td id="T_710a7_row5_col0" class="data row5 col0" >0.0</td>
#       <td id="T_710a7_row5_col1" class="data row5 col1" >0.0</td>
#       <td id="T_710a7_row5_col2" class="data row5 col2" >0.0</td>
#       <td id="T_710a7_row5_col3" class="data row5 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_710a7_level0_row6" class="row_heading level0 row6" >harmbench</th>
#       <td id="T_710a7_row6_col0" class="data row6 col0" >59.9</td>
#       <td id="T_710a7_row6_col1" class="data row6 col1" >67.8</td>
#       <td id="T_710a7_row6_col2" class="data row6 col2" >61.8</td>
#       <td id="T_710a7_row6_col3" class="data row6 col3" >53.2</td>
#     </tr>
#     <tr>
#       <th id="T_710a7_level0_row7" class="row_heading level0 row7" >injecagent_dh_ds_base</th>
#       <td id="T_710a7_row7_col0" class="data row7 col0" >99.4</td>
#       <td id="T_710a7_row7_col1" class="data row7 col1" >100.0</td>
#       <td id="T_710a7_row7_col2" cl

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
#
# 1. **Loading activations** from the ingestion pipeline (raw and SAE)
# 2. **Training classifiers** (LinearClassifier, DANNClassifier)
# 3. **LODO evaluation** for cross-dataset generalization
# 4. **Threshold strategies** for precision/recall tradeoffs
#
# ### Next Steps
#
# - See `02_on_the_fly_classification.ipynb` for real-time classification with SAE interpretation
# - See `03_evaluator_analysis.ipynb` for comparing baseline evaluators (Llama Guard, Prompt Guard)
